# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Dataset

data = pd.read_csv(r"C:\Users\sandy\sandeep\datasets\Customersatisfication.csv")

# %%
data
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
data.shape
# Out:
# (1500, 19)

# %%
data.isnull()
# Out:
#       CustomerID    Age  Gender  Income  VisitFrequency  AverageSpend  \
# 0          False  False   False   False           False         False
# 1          False  False   False   False           False         False
# 2          False  False   False   False           False         False
# 3          False  False   False   False           False         False
# 4          False  False   False   False           False         False
# ...          ...    ...     ...     ...             ...           ...
# 1495       False  False   False   False           False         False
# 1496       False  False   False   False           False         False
# 1497       False  False   False   False           False         False
# 1498       False  False   False   False           False         False
# 1499       False  False   False   False           False         False
#
#       PreferredCuisine  TimeOfVisit  GroupSize  DiningOccasion  MealType  \
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
data.head(20)
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0          654   35    Male   83380         Weekly     27.829142
# 1          655   19    Male   43623         Rarely    115.408622
# 2          656   41  Female   83737         Weekly    106.693771
# 3          657   43    Male   96768         Rarely     43.508508
# 4          658   55  Female   67937        Monthly    148.084627
# 5          659   42  Female   28860        Monthly    111.064696
# 6          660   20  Female  131104         Weekly    120.236707
# 7          661   51  Female  137882         Weekly    160.979098
# 8          662   27    Male  149638         Weekly     56.558632
# 9          663   32  Female  136145         Weekly     65.753455
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# ...

# %%
data.tail(20)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1480        2134   31    Male  130898         Weekly     81.665031
# 1481        2135   21    Male  144252          Daily     86.428886
# 1482        2136   52    Male  115595         Weekly     63.183463
# 1483        2137   31    Male   61751         Weekly     90.967958
# 1484        2138   41  Female   70528         Weekly    103.534241
# 1485        2139   63  Female  142579         Rarely     86.874446
# 1486        2140   24  Female  109032        Monthly     15.992567
# 1487        2141   47    Male   31938         Weekly     43.849076
# 1488        2142   25  Female  138277        Monthly    190.013468
# 1489        2143   58    Male   36994         Weekly    125.820956
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
# 1492        2146   20    Male   41041         Rarely     59.403047
# ...

# %%
data[data.index == 20]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 20         674   27  Female   41450         Weekly     14.677697
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion MealType  \
# 20          Chinese      Dinner          5    Celebration  Dine-in
#
#     OnlineReservation  DeliveryOrder  LoyaltyProgramMember  WaitTime  \
# 20                  0              0                     0  9.871497
#
#     ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 20              1           1               3                 0

# %%
#Isolating tweo or more rows using []
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(20,41))]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 20         674   27  Female   41450         Weekly     14.677697
# 21         675   40  Female   85259        Monthly     61.456659
# 22         676   20  Female  116507         Weekly    169.657810
# 23         677   51    Male   40666         Weekly     54.668755
# 24         678   21    Male   62296         Weekly    161.180604
# 25         679   40  Female   38099         Weekly    118.814236
# 26         680   51    Male  105609         Rarely     12.690321
# 27         681   68    Male   82470         Weekly    146.452729
# 28         682   49  Female   49402         Weekly     92.146409
# 29         683   59    Male   72461         Rarely    153.401540
# 30         684   68  Female   87140         Weekly    140.890006
# 31         685   18  Female   25148         Weekly    173.872310
# 32         686   35    Male   79963        Monthly    143.777624
# ...

# %%
data.iloc[5:50]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 5          659   42  Female   28860        Monthly    111.064696
# 6          660   20  Female  131104         Weekly    120.236707
# 7          661   51  Female  137882         Weekly    160.979098
# 8          662   27    Male  149638         Weekly     56.558632
# 9          663   32  Female  136145         Weekly     65.753455
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# 13         667   69    Male   38433          Daily     46.136865
# 14         668   58    Male   64870        Monthly     88.939098
# 15         669   54  Female  135616         Rarely    112.007541
# 16         670   59  Female  123325         Weekly     63.939240
# 17         671   42    Male   25569        Monthly    120.390191
# ...

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
data['Income'].value_counts()
# Out:
# Income
# 21547     2
# 25599     2
# 67998     2
# 38986     2
# 123053    2
#          ..
# 125084    1
# 129492    1
# 110795    1
# 45917     1
# 148333    1
# Name: count, Length: 1486, dtype: int64

# %%
data['MealType'].value_counts()
# Out:
# MealType
# Dine-in     751
# Takeaway    749
# Name: count, dtype: int64

# %%
top_5_Average_Spend= data.nlargest(5, 'AverageSpend')
print("\nTop 5 Average Spend:")
print(top_5_Average_Spend)
# Out:
# Top 5 Average Spend:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 171          825   47    Male   81504         Weekly    199.973527
# 750         1404   38    Male  119288         Rarely    199.924215
# 1137        1791   47  Female   51250         Weekly    199.796650
# 448         1102   32  Female  124333        Monthly    199.750152
# 1406        2060   24  Female   27805        Monthly    199.151084
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 171           Mexican       Lunch          3    Celebration   Dine-in
# 750           Mexican      Dinner          1         Casual  Takeaway
# 1137          Chinese      Dinner          6       Business  Takeaway
# 448           Mexican   Breakfast          9       Business   Dine-in
# 1406         American   Breakfast          7         Casual  Takeaway
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# ...

# %%
top_10_Food_Rating= data.nlargest(10, 'FoodRating')
print("\nTop 10 Food Rating:")
print(top_10_Food_Rating)
# Out:
# Top 10 Food Rating:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0          654   35    Male   83380         Weekly     27.829142
# 1          655   19    Male   43623         Rarely    115.408622
# 3          657   43    Male   96768         Rarely     43.508508
# 5          659   42  Female   28860        Monthly    111.064696
# 16         670   59  Female  123325         Weekly     63.939240
# 31         685   18  Female   25148         Weekly    173.872310
# 40         694   67    Male   70219        Monthly    114.852870
# 44         698   50  Female  123950         Rarely    190.027105
# 56         710   19  Female   81440         Rarely     79.742895
# 63         717   21    Male   94550        Monthly     82.685349
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0           Chinese   Breakfast          3       Business  Takeaway
# 1          American      Dinner          1         Casual   Dine-in
# ...

# %%
top_10_Service_Rating= data.nlargest(10, 'ServiceRating')
print("\nTop 10 Service Rating:")
print(top_10_Service_Rating)
# Out:
# Top 10 Service Rating:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1          655   19    Male   43623         Rarely    115.408622
# 6          660   20  Female  131104         Weekly    120.236707
# 12         666   32  Female  143471        Monthly    156.130808
# 26         680   51    Male  105609         Rarely     12.690321
# 29         683   59    Male   72461         Rarely    153.401540
# 35         689   46    Male   84767         Weekly     11.047363
# 36         690   38  Female   35769         Rarely     72.331022
# 38         692   23  Female   70427         Weekly    154.462649
# 45         699   28  Female  105851         Weekly    157.191640
# 47         701   59  Female  136805         Weekly     69.552242
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1          American      Dinner          1         Casual   Dine-in
# 6            Indian       Lunch          6       Business   Dine-in
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
data.shape[0]
# Out:
# 1500

# %%
data.shape[1]
# Out:
# 19

# %%
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
plt.figsize = (10,20)
sns.histplot(data ,y="CustomerID",x="PreferredCuisine")
# Out:
# <Axes: xlabel='PreferredCuisine', ylabel='CustomerID'>

# %%
plt.figsize = (100,100)
sns.displot(data, y="DiningOccasion",x="MealType")

# %%
plt.figsize = (10,20)
sns.relplot(data ,y="CustomerID", x="VisitFrequency")

# %%
plt.figsize = (100,100)
sns.barplot(data , x="Gender", y="TimeOfVisit")
# Out:
# <Axes: xlabel='Gender', ylabel='TimeOfVisit'>

# %%
sns.lmplot(y="WaitTime", x="Age", data=data)

# %%
sns.relplot(data=data, y="Income", x="AverageSpend", kind="line")

# %%
plt.figsize = (100,100)
sns.catplot(data=data, x="Gender", y="GroupSize")

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='AmbianceRating', hue='TimeOfVisit', bins=10, kde=True, multiple="stack")

# Add labels
plt.xlabel('AmbianceRating')
plt.ylabel('TimeOfVisit	')

# Show the plot
plt.show()
# Out:
# C:\Users\sandy\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
status_counts = data['OnlineReservation'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
sns.boxplot(x="PreferredCuisine", y="DiningOccasion", data=data)

plt.xlabel("PreferredCuisine")
plt.ylabel("DiningOccasion")
plt.show()

# %%
sns.violinplot(x="MealType", y="DeliveryOrder", data=data)

plt.xlabel("MealType")
plt.ylabel("DeliveryOrder")
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='crest', linewidths=0.5)

plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()
